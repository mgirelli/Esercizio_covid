# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataframe = pd.read_csv('data_covid.csv', sep=',', index_col='data', parse_dates=True)

# %%
dataframe.head()
# Out:
#                     stato  codice_regione denominazione_regione        lat  \
# data
# 2020-02-24 18:00:00   ITA              13               Abruzzo  42.351222
# 2020-02-24 18:00:00   ITA              17            Basilicata  40.639471
# 2020-02-24 18:00:00   ITA              18              Calabria  38.905976
# 2020-02-24 18:00:00   ITA              15              Campania  40.839566
# 2020-02-24 18:00:00   ITA               8        Emilia-Romagna  44.494367
#
#                           long  ricoverati_con_sintomi  terapia_intensiva  \
# data
# 2020-02-24 18:00:00  13.398438                       0                  0
# 2020-02-24 18:00:00  15.805148                       0                  0
# 2020-02-24 18:00:00  16.594402                       0                  0
# 2020-02-24 18:00:00  14.250850                       0                  0
# 2020-02-24 18:00:00  11.341721                      10                  2
#
# ...

# %%
class plot_covid:
    def __init__(self, data):
        self.dataframe = data
    def plot_una_regione(self, nome, value):
        self.regione = nome
        self.ricovero = value
        data_tagliato = self.dataframe.loc[self.dataframe.denominazione_regione == self.regione]
        plt.plot(data_tagliato.index, data_tagliato[self.ricovero], linewidth=1.0)
        plt.show()
    def plot_ogni_regione(self, value):
        for nome, dati in self.dataframe.groupby('denominazione_regione'):
            plt.plot(dati.index, dati[value], linewidth=1.0, label = f'{nome}')
        plt.legend(prop={'size': 6})
        plt.show()

# %%
obj = plot_covid(dataframe)

# %%
obj.plot_una_regione('Veneto', 'ricoverati_con_sintomi')

# %%
obj.plot_ogni_regione('ricoverati_con_sintomi')
